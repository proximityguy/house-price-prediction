# %%
import sys
assert sys.version_info >= (3,5)
# checking compatible python version for modern scikit-learn and pandas

import sklearn
assert sklearn.__version__ >= "0.20"
# some transformers require >= 0.20

import numpy as np
import os
# NumPy for numerical works, os for filesystem paths

# plotting inline in notebook + style
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
# redable plots in the notebook

# %%
HOUSING_PATH = os.path.join("C:/Users/HP/Desktop/jupyter/jbooks/house_price_prediction/data/housing.csv")
# dataset file path
